# %%
# 接下来基于CDA2级教程8.5.4模型评估使用ROC曲线进行模型评估
# X_test=test.drop(columns=["is_fraud"])#同上方出现原formula4中state变量冲突,此处暂时搁置
# X_test=test(columns=["amt","category","state"])#尝试进行列的指定调整,出现DATAFRAME格式报错，属于type error，继续进行更改
# print(type(X_test))#查询X_test数据形式
# 发现错误为第45行出错,进行修改
# X_test=test[["amt"]]
# 报错原因为测试集state列中含AK,AL等大量
# predictions=lg_m1.predict(X_test)
# test["prediction"]=predictions
# acc_m=sum(test["prediction"]==test["churn"])/np.float(len(test))
# 此处原本教程为使用,但运行时为BOOL格式,出现报错,故查询资料优化替代
# acc_m=np.mean(test["prediction"]==test["is_fraud"])#使用numpy库的mean对bool格式进行计算模型准确性
# print('The accuracy is %.2f'%acc_m )
